# %%
from aereo.backends import LocalProcessBackend
from aereo.client import AereoClient
from aereo.pipeline import ExtractionJob


client = AereoClient()
job = ExtractionJob.load_from_config(
    config_dir="config",
    config_name="job_sentinel3.yaml",
)

# %%
# Search
search_results = client.search(job.search)
print(f"✓ Found {len(search_results)} scenes")

# %%
# Prepare
print("\n📦 Preparing tasks...")
tasks = client.prepare_tasks(
    search_results=search_results,
    job=job,
    cells_per_task=1,
)
print(f"✓ Prepared {len(tasks)} tasks")

# %%
# Extract
print("\n⛏️ Extracting...")
backend = LocalProcessBackend(max_workers=1)
artifacts = client.execute_tasks(tasks, backend=backend)
print(f"✓ Extracted {len(artifacts)} artifacts")

# %%
from aereo.viz import plot_artifact_patches

plot_artifact_patches(
    artifacts, vmin=-1, vmax=1, ds_factor=1, cmap="RdBu", colorbar_label="ndvi"
)
